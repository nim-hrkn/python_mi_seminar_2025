# %% [markdown]
# User:
#
# ```
# Pythonの以下のコードを書いてください。
# scikit-learnのGridSearchCVを用いてsupport vector machineのハイパーパラメタを最適化する例を書いてください。
# ```
#
#
# Microsoft Copilot:
#
# ```
# from sklearn import svm, datasets
# from sklearn.model_selection import GridSearchCV
#
# # データセットをロードします
# iris = datasets.load_iris()
#
# # パラメータグリッドを定義します
# param_grid = {'C': [0.1, 1, 10, 100, 1000],
#               'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#               'kernel': ['rbf']}
#
# # SVMモデルを作成します
# svc = svm.SVC()
#
# # GridSearchCVを作成します
# grid = GridSearchCV(svc, param_grid, refit = True, verbose = 3)
#
# # モデルを訓練します
# grid.fit(iris.data, iris.target)
#
# # 最適なパラメータを表示します
# print("最適なパラメータ: ", grid.best_params_)
# print("最適なスコア: ", grid.best_score_)
#
# ```

# %%
from sklearn import svm, datasets
from sklearn.model_selection import GridSearchCV

# データセットをロードします
iris = datasets.load_iris()

# パラメータグリッドを定義します
param_grid = {'C': [0.1, 1, 10, 100, 1000], 
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
              'kernel': ['rbf']} 

# SVMモデルを作成します
svc = svm.SVC()

# GridSearchCVを作成します
grid = GridSearchCV(svc, param_grid, refit = True, verbose = 3)

# モデルを訓練します
grid.fit(iris.data, iris.target)

# 最適なパラメータを表示します
print("最適なパラメータ: ", grid.best_params_)
print("最適なスコア: ", grid.best_score_)

# %% [markdown]
# User:
#
# ```
# Pythonの以下のコードを書いてください。
# scikit-learnのGridSearchCVを用いてsupport vector machineのハイパーパラメタを最適化する例を書いてください。
# SVC(kernel='poly')を用いてください。
# ```
#
# Microsoft Copilot:
#
# ```
# from sklearn import svm, datasets
# from sklearn.model_selection import GridSearchCV
#
# # データセットをロードします
# iris = datasets.load_iris()
#
# # パラメータグリッドを定義します
# param_grid = {'C': [0.1, 1, 10, 100, 1000],
#               'degree': [2, 3, 4, 5],
#               'kernel': ['poly']}
#
# # SVMモデルを作成します
# svc = svm.SVC(kernel='poly')
#
# # GridSearchCVを作成します
# grid = GridSearchCV(svc, param_grid, refit = True, verbose = 3)
#
# # モデルを訓練します
# grid.fit(iris.data, iris.target)
#
# # 最適なパラメータを表示します
# print("最適なパラメータ: ", grid.best_params_)
# print("最適なスコア: ", grid.best_score_)
#
# ```

# %%
from sklearn import svm, datasets
from sklearn.model_selection import GridSearchCV

# データセットをロードします
iris = datasets.load_iris()

# パラメータグリッドを定義します
param_grid = {'C': [0.1, 1, 10, 100, 1000], 
              'degree': [2, 3, 4, 5],
              'kernel': ['poly']} 

# SVMモデルを作成します
svc = svm.SVC(kernel='poly')

# GridSearchCVを作成します
grid = GridSearchCV(svc, param_grid, refit = True, verbose = 3)

# モデルを訓練します
grid.fit(iris.data, iris.target)

# 最適なパラメータを表示します
print("最適なパラメータ: ", grid.best_params_)
print("最適なスコア: ", grid.best_score_)

# %% [markdown]
# User:
#
# ```
# Pythonの以下のコードを書いてください。
# scikit-learnのGridSearchCVを用いてsupport vector machineのハイパーパラメタをF1スコアで最適化する例を書いてください。
# SVC(kernel='poly')を用いてください。
# ```
#
#
# Microsoft Copilot:
#
#
# ```
# from sklearn import svm, datasets
# from sklearn.model_selection import GridSearchCV
# from sklearn.metrics import make_scorer, f1_score
#
# # データセットをロードします
# iris = datasets.load_iris()
#
# # パラメータグリッドを定義します
# param_grid = {'C': [0.1, 1, 10, 100, 1000],
#               'degree': [2, 3, 4, 5],
#               'kernel': ['poly']}
#
# # SVMモデルを作成します
# svc = svm.SVC(kernel='poly')
#
# # F1スコアをスコアリング関数として設定します
# scorer = make_scorer(f1_score, average='micro')
#
# # GridSearchCVを作成します
# grid = GridSearchCV(svc, param_grid, scoring=scorer, refit = True, verbose = 3)
#
# # モデルを訓練します
# grid.fit(iris.data, iris.target)
#
# # 最適なパラメータを表示します
# print("最適なパラメータ: ", grid.best_params_)
# print("最適なスコア: ", grid.best_score_)
# ```
# ... また、このコードは全てのデータを訓練に使用していますので、実際の問題ではデータを訓練セットとテストセットに分割することをお勧めします。ご参考までに。.

# %%
from sklearn import svm, datasets
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer, f1_score

# データセットをロードします
iris = datasets.load_iris()

# パラメータグリッドを定義します
param_grid = {'C': [0.1, 1, 10, 100, 1000], 
              'degree': [2, 3, 4, 5],
              'kernel': ['poly']} 

# SVMモデルを作成します
svc = svm.SVC(kernel='poly')

# F1スコアをスコアリング関数として設定します
scorer = make_scorer(f1_score, average='micro')

# GridSearchCVを作成します
grid = GridSearchCV(svc, param_grid, scoring=scorer, refit = True, verbose = 3)

# モデルを訓練します
grid.fit(iris.data, iris.target)

# 最適なパラメータを表示します
print("最適なパラメータ: ", grid.best_params_)
print("最適なスコア: ", grid.best_score_)

# %%
# X,yを030.050に合わせて変更する。

import numpy as np
import pandas as pd
import matplotlib.pylab as plt
# %matplotlib inline
import get_data 
df, descriptor_names, target_name = get_data.load('ZB_WZ_all')

RANDOM_STATE = 1
Xraw = df.loc[:, descriptor_names].values
yraw = df.loc[:, target_name].values
from sklearn.preprocessing import StandardScaler
y = yraw > 0
scaler = StandardScaler()
scaler.fit(Xraw)
X = scaler.transform(Xraw)



from sklearn import svm
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer, f1_score

# パラメータグリッドを定義します
param_grid = {'C': [0.1, 1, 10, 100, 1000], 
              'degree': [2, 3, 4, 5],
              'kernel': ['poly']} 

# SVMモデルを作成します
svc = svm.SVC(kernel='poly')

# F1スコアをスコアリング関数として設定します
scorer = make_scorer(f1_score, average='micro')

# GridSearchCVを作成します
grid = GridSearchCV(svc, param_grid, scoring=scorer, refit = True, verbose = 3)

# モデルを訓練します
grid.fit(X,y)

# 最適なパラメータを表示します
print("最適なパラメータ: ", grid.best_params_)
print("最適なスコア: ", grid.best_score_)
