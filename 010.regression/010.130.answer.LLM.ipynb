# %% [markdown]
# # 最初の試行
#
# User:
#
# ```
# 添付ファイルの名前を'x5_sin.csv'とします。
# 以下のPythonコードを作成してください。
# # データ取得
# 'x5_sin.csv'ファイルをデータフレーム(df_obs)として読んでください。
# 変数XrawをDESCRIPTOR_NAMESカラムから読んでください。
# DESCRIPTOR_NAMES = ['x1', 'x2', 'x3', 'x4', 'x5', 'x6']
# 変数yをTARGET_NAMEカラムから読んでください。
# TARGET_NAME = "y"
# # データ加工
# StandardScalerでXrawを変数Xに変換してください。
# # 予測モデル学習
# 10回交差検定を行い、R2スコアを計算して表示してください。
# Lassoのhyperparameterは最適化したLasso予測回帰モデル(model)を作成してください
# Lasso予測回帰モデル(model)の予測値(yp)を計算してください。
# # 可視化
# y vs ypの図を書いてください。
# # 条件
# scikit-learnを用いてください。
# ```
#
# ChatGPT4 (コード部分のみ）
#
# ```
# import pandas as pd
# from sklearn.preprocessing import StandardScaler
# from sklearn.linear_model import Lasso
# from sklearn.model_selection import cross_val_score, KFold
# import matplotlib.pyplot as plt
#
# # Load the data
# df_obs = pd.read_csv('/mnt/data/x5_sin.csv')
#
# # Read variables
# DESCRIPTOR_NAMES = ['x1', 'x2', 'x3', 'x4', 'x5', 'x6']
# TARGET_NAME = "y"
#
# Xraw = df_obs[DESCRIPTOR_NAMES]
# y = df_obs[TARGET_NAME]
#
# # Data preprocessing
# scaler = StandardScaler()
# X = scaler.fit_transform(Xraw)
#
# # Train prediction model
# model = Lasso()
# kf = KFold(n_splits=10)
# r2_scores = cross_val_score(model, X, y, cv=kf, scoring='r2')
# print("R2 Scores: ", r2_scores)
#
# # Fit the model
# model.fit(X, y)
#
# # Predict
# yp = model.predict(X)
#
# # Visualization
# plt.scatter(y, yp)
# plt.xlabel("y")
# plt.ylabel("yp")
# plt.title("y vs yp")
# plt.show()
# ```
#
# hyperparameterの最適化がされていない。
# また、kf = KFold(n_splits=10)でshuffle=Falseであることに注意する。

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Lasso
from sklearn.model_selection import cross_val_score, KFold
import matplotlib.pyplot as plt

# Load the data
df_obs = pd.read_csv('../data_calculated/x5_sin.csv')

# Read variables
DESCRIPTOR_NAMES = ['x1', 'x2', 'x3', 'x4', 'x5', 'x6']
TARGET_NAME = "y"

Xraw = df_obs[DESCRIPTOR_NAMES]
y = df_obs[TARGET_NAME]

# Data preprocessing
scaler = StandardScaler()
X = scaler.fit_transform(Xraw)

# Train prediction model
model = Lasso()
kf = KFold(n_splits=10)
r2_scores = cross_val_score(model, X, y, cv=kf, scoring='r2')
print("R2 Scores: ", r2_scores)

# Fit the model
model.fit(X, y)

# Predict
yp = model.predict(X)

# Visualization
plt.scatter(y, yp)
plt.xlabel("y")
plt.ylabel("yp")
plt.title("y vs yp")
plt.show()
