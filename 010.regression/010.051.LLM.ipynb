# %%
# 追加部分
import os
import pandas as pd

ROOT = ".."
filename = f"{ROOT}/data_calculated/x5_sin.csv"
DESCRIPTOR_NAMES = ['x1', 'x2', 'x3', 'x4', 'x5', 'x6']
TARGET_NAME = "y"
df_obs = pd.read_csv(filename)
Xraw = df_obs.loc[:, DESCRIPTOR_NAMES].values
y = df_obs.loc[:, TARGET_NAME].values

# %% [markdown]
# User:
# ```
# 以下のPythonコードを書いてください。
#
# 1. **標準化:** `StandardScaler`を用いて、特徴データ`Xraw`を標準化します。これにより、データのスケールを平均0、標準偏差1に調整します。
#
# 2. **データ分割:** `train_test_split`で、標準化されたデータ`X`と目的変数`y`を訓練用とテスト用に分割します。テストセットは全体の25%で、ランダムにシャッフルされます。
#
# 3. **線形回帰モデルの訓練:** `LinearRegression`を使って線形回帰モデルを作成し、訓練データにフィットさせます。
#
# 4. **モデルの係数と切片の出力:** 訓練されたモデルの係数と切片を出力します。
#
# 5. **予測:** モデルを使って、訓練データとテストデータの両方に対する予測を行います。
#
# # 条件
# データセットは Diabetes datasetを用いてください。
#
# ```
#
#
# ChatGPT4:
#
# ```python
# from sklearn import datasets
# from sklearn.preprocessing import StandardScaler
# from sklearn.model_selection import train_test_split
# from sklearn.linear_model import LinearRegression
#
# # データセットのロード
# Xraw, y = datasets.load_diabetes(return_X_y=True)
#
# # 標準化
# scaler = StandardScaler()
# X = scaler.fit_transform(Xraw)
#
# # データ分割
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, shuffle=True, random_state=1)
#
# # 線形回帰モデルの訓練
# reg = LinearRegression()
# reg.fit(X_train, y_train)
#
# # モデルの係数と切片の出力
# print("coef", reg.coef_)
# print("intercept", reg.intercept_)
#
# # 予測
# y_train_pred = reg.predict(X_train)
# y_test_pred = reg.predict(X_test)
#
# # 予測結果の先頭5つを表示（参考のため）
# y_train_pred[:5], y_test_pred[:5]
# ```

# %%
# scikit-learnのデータセットを使わないように書きしなおす。

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# 標準化
scaler = StandardScaler()
X = scaler.fit_transform(Xraw)

# データ分割
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, shuffle=True, random_state=1)

# 線形回帰モデルの訓練
reg = LinearRegression()
reg.fit(X_train, y_train)

# モデルの係数と切片の出力
print("coef", reg.coef_)
print("intercept", reg.intercept_)

# 予測
y_train_pred = reg.predict(X_train)
y_test_pred = reg.predict(X_test)

# 予測結果の先頭5つを表示（参考のため）
y_train_pred[:5], y_test_pred[:5]

# %% [markdown]
# User:
#
# ```
# 以下のPythonコードを生成してください。
#
# 2つのサブプロットを持つ図を作成します。`Xraw` は規格化されていない説明変数で、`X` は規格化された説明変数です。どちらも二次元の行列です。
#
# 最初のサブプロットでは、`Xraw` の最初の列（`Xraw[:,0]`）を x 軸の値として、それ以外の列（`Xraw[:,1:]`）を y 軸の値としてプロットしています。点と線で接続されています。
#
# 二番目のサブプロットでは、同様に標準化されたデータ `X` の最初の列を x 軸に、それ以外の列を y 軸にプロットしています。
#
# x 軸と y 軸にラベルを設定してください。
#
#
# ```
#
# ChatGPT4:
#
# ```python
#
# # 必要なライブラリをインポートします。
# import matplotlib.pyplot as plt
# from sklearn import datasets
# from sklearn.preprocessing import StandardScaler
#
# # データセットをロードします。
# Xraw, y = datasets.load_diabetes(return_X_y=True)
#
# # 標準化を実施します。
# scaler = StandardScaler()
# X = scaler.fit_transform(Xraw)
#
# # 図を作成し、2つのサブプロットを用意します。
# fig, axes = plt.subplots(1, 2, figsize=(12, 6))
#
# # 最初のサブプロットにXrawの最初の特徴量をx軸に、残りの特徴量をy軸にプロットします。
# axes[0].plot(Xraw[:, 0], Xraw[:, 1:], ".-")
# axes[0].set_xlabel("Xraw Feature 1")
# axes[0].set_ylabel("Other Features")
#
# # 2番目のサブプロットに標準化後のXの最初の特徴量をx軸に、残りの特徴量をy軸にプロットします。
# axes[1].plot(X[:, 0], X[:, 1:], ".-")
# axes[1].set_xlabel("Standardized Feature 1")
# axes[1].set_ylabel("Other Features")
#
# # 図を表示します。
# plt.tight_layout()
# plt.show()
# ```

# %%
import matplotlib.pyplot as plt

# 図を作成し、2つのサブプロットを用意します。
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# 最初のサブプロットにXrawの最初の特徴量をx軸に、残りの特徴量をy軸にプロットします。
axes[0].plot(Xraw[:, 0], Xraw[:, 1:], ".-")
axes[0].set_xlabel("Xraw Feature 1")
axes[0].set_ylabel("Other Features")

# 2番目のサブプロットに標準化後のXの最初の特徴量をx軸に、残りの特徴量をy軸にプロットします。
axes[1].plot(X[:, 0], X[:, 1:], ".-")
axes[1].set_xlabel("Standardized Feature 1")
axes[1].set_ylabel("Other Features")

# 図を表示します。
plt.tight_layout()
plt.show()

# %% [markdown]
# User:
#
#
# 以下のPythonコードを過程毎に３００字位内で説明してください。
#
# ```
# from sklearn.model_selection import train_test_split
# Xtrain, Xtest, ytrain, ytest = \
#                         train_test_split(X, y, test_size=0.25,
#                                          shuffle=True, random_state=1)
# from sklearn.linear_model import LinearRegression
# reg = LinearRegression()
# reg.fit(Xtrain, ytrain)
# print("coef", reg.coef_)
# print("intercept", reg.intercept_)
# ytrainp = reg.predict(Xtrain)
# ytestp = reg.predict(Xtest)
# from sklearn.metrics import r2_score
# from sklearn.metrics import mean_squared_error
# from sklearn.metrics import mean_absolute_error
# rmse = np.sqrt(mean_squared_error(ytest, ytestp))
# mae = mean_absolute_error(ytest, ytestp)
# r2 = r2_score(ytest, ytestp)
# print("RMSE, MAE, R2", rmse, mae, r2)
# ```
#
#
# ChatGPT4:
#
# ```
# このPythonコードは、線形回帰モデルを用いて機械学習の一連のプロセスを実行するものです。各ステップを簡潔に説明します：
#
# 1. **データセットの分割**:
#    - `train_test_split`を使い、元のデータセット（`X`と`y`）を訓練データ（`Xtrain`, `ytrain`）とテストデータ（`Xtest`, `ytest`）に分割します。テストデータのサイズは全体の25%です。`shuffle=True`によりデータはランダムにシャッフルされ、`random_state=1`によりこのランダム過程は再現可能になります。
#
# 2. **モデルの訓練**:
#    - `LinearRegression`モデルをインポートし、インスタンスを作成します。
#    - `reg.fit(Xtrain, ytrain)`により訓練データを使用してモデルを訓練します。
#
# 3. **モデルのパラメータ表示**:
#    - 訓練されたモデルの回帰係数（`coef`）と切片（`intercept`）を表示します。
#
# 4. **予測の実施**:
#    - `reg.predict`を用いて、訓練データとテストデータの予測値を生成します。
#
# 5. **モデル評価**:
#    - テストデータに対するRMSE（平均二乗誤差の平方根）、MAE（平均絶対誤差）、R^2（決定係数）を計算します。
#
# 6. **評価結果の表示**:
#    - 計算されたRMSE、MAE、R^2の値を出力します。
#
# このコードは、データの前処理（分割）、モデルの訓練と評価を通じて、機械学習の基本的なワークフローを示しています。
# ```

# %% [markdown]
# User:
#
# ```
# 以下のPythonコードを作成してください。
# # 入力X:説明変数
# y: 目的変数
# # 過程
# 1. **データセットの分割**:
#    - `train_test_split`を使い、元のデータセット（`X`と`y`）を訓練データ（`Xtrain`, `ytrain`）とテストデータ（`Xtest`, `ytest`）に分割します。テストデータのサイズは全体の25%です。``random_state=1`にデータはランダムにシャッフルします。
# 2. **モデルの訓練**:
#    - `LinearRegression`モデルをインポートし、インスタンスを作成します。
#    - `reg.fit(Xtrain, ytrain)`により訓練データを使用してモデルを訓練します。
# 3. **モデルのパラメータ表示**:
#    - 訓練されたモデルの回帰係数（`coef`）と切片（`intercept`）を表示します。
# 4. **予測の実施**:
#    - `reg.predict`を用いて、訓練データとテストデータの予測値を生成します。
# 5. **モデル評価**:
#    - テストデータに対するRMSE（平均二乗誤差の平方根）、MAE（平均絶対誤差）、R^2（決定係数）を計算します。
# 6. **評価結果の表示**:
#    - 計算されたRMSE、MAE、R^2の値を出力します。
# ```
#
# ChatGPT4:
#
# ```
# # 必要なモジュールのインポート
# from sklearn.model_selection import train_test_split
# from sklearn.linear_model import LinearRegression
# from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
# import numpy as np
#
# # データセットの定義（実際のデータに置き換える）
# # X, y
#
# # 1. データセットの分割
# Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, test_size=0.25, random_state=1)
#
# # 2. モデルの訓練
# reg = LinearRegression()
# reg.fit(Xtrain, ytrain)
#
# # 3. モデルのパラメータ表示
# print("Coefficients:", reg.coef_)
# print("Intercept:", reg.intercept_)
#
# # 4. 予測の実施
# ytrain_pred = reg.predict(Xtrain)
# ytest_pred = reg.predict(Xtest)
#
# # 5. モデル評価
# rmse = np.sqrt(mean_squared_error(ytest, ytest_pred))
# mae = mean_absolute_error(ytest, ytest_pred)
# r2 = r2_score(ytest, ytest_pred)
#
# # 6. 評価結果の表示
# print("RMSE:", rmse)
# print("MAE:", mae)
# print("R^2:", r2)
#
# ```

# %%
# 必要なモジュールのインポート
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np


# 1. データセットの分割
Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, test_size=0.25, random_state=1)

# 2. モデルの訓練
reg = LinearRegression()
reg.fit(Xtrain, ytrain)

# 3. モデルのパラメータ表示
print("Coefficients:", reg.coef_)
print("Intercept:", reg.intercept_)

# 4. 予測の実施
ytrain_pred = reg.predict(Xtrain)
ytest_pred = reg.predict(Xtest)

# 5. モデル評価
rmse = np.sqrt(mean_squared_error(ytest, ytest_pred))
mae = mean_absolute_error(ytest, ytest_pred)
r2 = r2_score(ytest, ytest_pred)

# 6. 評価結果の表示
print("RMSE:", rmse)
print("MAE:", mae)
print("R^2:", r2)
